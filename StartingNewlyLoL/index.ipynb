# %%
name = "Ada Loveless"
print(name.title())
# Out:
# Ada Loveless

# %%
ages = [12,21,123,121, "Jay"]
ages.append("Joy")
ages.append(23)
ages.reverse()
print(ages)
# Out:
# [23, 'Joy', 'Jay', 121, 123, 21, 12]
